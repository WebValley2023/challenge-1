# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import calendar

# %%
peak_days=[]
Appa=pd.read_csv(
    "DataSet_Riva_garda.csv",
    na_values="n.d.",
)
# start_data = "2013-01-01"
# end_data = "2014-01-01"
Appa["Data"]=pd.to_datetime(Appa["Data"])
Appa.sort_values(by="Data", inplace=True)
Appa=Appa.set_index("Data",drop=True)
#Appa = Appa[start_data:end_data]
df3= pd.DataFrame(pd.date_range('2019-11-15 00:00:00', '2020-11-15 00:00:00', freq="1H")).set_index(0)
Appa=df3.join(Appa)

for x in range(1,6):
    Giorno=Appa[5+(24*(x-1)):(24*x)+5]

    plt.figure(figsize=(10, 6))  
    plt.plot(Giorno.index, Giorno["Ozone"],marker='o',label="Ozone")  
    plt.xlabel("Time")
    plt.ylabel("Ozone")
    plt.grid()
    # plt.xlim(pd.to_datetime(start_data),pd.to_datetime(end_data))

    plt.plot(Giorno.index, Giorno["Sol_rad"]/10, label="Sol_rad")  
    plt.legend()
    plt.title("DAY: "+str(Giorno.index[0].day)+"-"+str(Giorno.index[0].month)+"-"+str(Giorno.index[0].year))
    plt.show()

    #print(Giorno.indexy)







    #Appa.drop(index=Appa.index[:24], axis=0, inplace=True)

# %%
for data in df_peak_day.Data:
   print(data)
   Appa.set_index("Data",inplace=True)
   pos=Appa.index.get_loc[data+" 00:00:00"]
# Out:
# 15-11-2019
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10192\3456041929.py in ?()
#       1 for data in df_peak_day.Data:
#       2    print(data)
# ----> 3    Appa.set_index("Data",inplace=True)
#       4    pos=Appa.index.get_loc[data+" 00:00:00"]
#
# c:\Users\rajaf\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Data'] are in the columns"

# %%
Giorno.index[0].



#import missingno as msno
#msno.matrix(Appa)

#testdf = Appa.resample
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 Giorno.index[0].all
#       5 #import missingno as msno
#       6 #msno.matrix(Appa)
#       7
#       8 #testdf = Appa.resample
#
# AttributeError: 'Timestamp' object has no attribute 'all'

# %%
msno.matrix(df4)

# %%
Appa.isna().sum()
#test = Appa.interpolate(method="linear", direction="both", limit=2)
Appa= Appa.drop_duplicates()
Appa = Appa

Appa
# Out:
# PM10                  1
# Nitrogen dioxide    142
# Ozone                54
# Air_humidity          0
# Sol_rad               0
# Temperature           0
# Wind_speed            0
# Qual                  0
# dtype: int64

# %%
Appa=pd.read_csv(
    "DataSet_Riva_garda.csv",
    na_values="n.d.",
)

Appa["Data"]=pd.to_datetime(Appa["Data"])
Appa.sort_values(by="Data", inplace=True)
Appa=Appa.set_index("Data",drop=True)
#Appa = Appa.resample("M").mean()

plt.figure(figsize=(20, 10))  
plt.plot(Appa.index, Appa["Ozone"],marker='o', label="Ozone")  
plt.xlabel("Time")
plt.ylabel("Ozone")
plt.grid()
plt.xlim(pd.to_datetime(start_data),pd.to_datetime(end_data))
plt.plot(Appa.index, Appa["Sol_rad"]/10)  
plt.xlim(pd.to_datetime(start_data),pd.to_datetime(end_data))
plt.legend()
plt.show()
