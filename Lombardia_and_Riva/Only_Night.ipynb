# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression

# %%
start_date="2021-12-10"
end_date="2022-12-10"

# %%
df_Riva=pd.read_csv(
    "..\\Riva\\DataSet_Riva_garda.csv",
    na_values="n.d."
)

df_Riva["Data"]=pd.to_datetime(df_Riva["Data"])
df_Riva.sort_values(by="Data", inplace=True)
df_Riva.set_index('Data', inplace=True)
df_Riva= df_Riva.loc[start_date:end_date,:]
df_Riva.drop(["Unnamed: 0"],axis=1,inplace=True)
df_Riva=df_Riva.reset_index().drop_duplicates(subset="Data")
df_Riva
# Out:
#                     Data      1   NO2  Ozone  Air_humidity  Sol_rad  \
# 0    2021-12-10 00:00:00  15533  35.0    4.0          2.90      0.0
# 1    2021-12-10 01:00:00  15534  31.0    7.0          3.80      0.0
# 2    2021-12-10 02:00:00  15535  24.0   14.0          4.70      0.0
# 3    2021-12-10 03:00:00  15536  20.0   22.0          5.10      0.0
# 4    2021-12-10 04:00:00  15537  18.0   26.0          5.10      0.0
# ...                  ...    ...   ...    ...           ...      ...
# 8776 2022-12-10 19:00:00  24309  31.0    4.0          6.35      0.0
# 8777 2022-12-10 20:00:00  24310  32.0    5.0          7.50      0.0
# 8778 2022-12-10 21:00:00  24311  31.0    5.0          7.10      0.0
# 8779 2022-12-10 22:00:00  24312  29.0    5.0          6.45      0.0
# 8780 2022-12-10 23:00:00  24313  28.0    6.0          6.80      0.0
#
#       Temperature  Wind_speed   Qual  Station 1 - Temp (°C)  \
# 0            2.75        2.90  145.0                  18.75
# 1            3.20        3.80  145.0                  18.75
# 2            3.70        4.70  145.0                  18.78
# 3            3.55        5.10  145.0                  18.77
# 4            2.55        5.10  145.0                  18.76
# ...           ...         ...    ...                    ...
# 8776         7.45        6.35  145.0                  18.96
# 8777         7.80        7.50  145.0                  18.96
# 8778         7.25        7.10  145.0                  18.90
# 8779         7.70        6.45  145.0                  18.90
# 8780         6.95        6.80  145.0                  18.88
#
#       Station 1 - HDO % (%Sat)  Station 1 - HDO (mg/l)
# 0                         97.0                    9.04
# 1                         96.8                    9.02
# 2                         96.4                    8.98
# 3                         96.2                    8.96
# 4                         96.1                    8.96
# ...                        ...                     ...
# 8776                      98.4                    9.13
# 8777                     101.1                    9.38
# 8778                      98.3                    9.13
# 8779                      96.7                    8.98
# 8780                      96.9                    9.01
#
# [8781 rows x 12 columns]

# %%
df_Lomb=pd.read_csv(
    "..\\Lombardia\\lomb_tot.csv",
    na_values="n.d."
)

df_Lomb ["Data"]=pd.to_datetime(df_Lomb ["Data"])
df_Lomb.sort_values(by="Data", inplace=True)
df_Lomb .set_index('Data', inplace=True)
df_Lomb= df_Lomb.loc[start_date:end_date,:]
df_Lomb.drop(["Unnamed: 0"],axis=1,inplace=True)
df_Lomb=df_Lomb.reset_index().drop_duplicates(subset="Data")
df_Lomb
# Out:
#                     Data  Ozone  Humidity  Sol_rad  Wind_speed  Wind_dir  Temp
# 0    2021-12-10 00:00:00    7.5     100.0      0.0         2.5     317.0   3.9
# 1    2021-12-10 01:00:00   20.8     100.0      0.0         2.8     331.0   3.5
# 2    2021-12-10 02:00:00    0.5     100.0      0.0         2.9     298.0   3.4
# 3    2021-12-10 03:00:00    0.7     100.0      0.0         3.0     304.0   3.4
# 4    2021-12-10 04:00:00    1.5     100.0      0.0         3.2     299.0   3.5
# ...                  ...    ...       ...      ...         ...       ...   ...
# 8779 2022-12-10 19:00:00    0.5      99.7      0.0         0.7     320.0   8.1
# 8780 2022-12-10 20:00:00    0.5      99.2      0.0         1.8     243.0   8.4
# 8781 2022-12-10 21:00:00    0.4     100.0      0.0         2.5     245.0   7.7
# 8782 2022-12-10 22:00:00    0.6      99.7      0.0         2.0     244.0   7.0
# 8783 2022-12-10 23:00:00    0.6     100.0      0.0         1.4     218.0   6.6
#
# [8784 rows x 7 columns]

# %%
df_Finale=pd.DataFrame()

df_Finale.insert(0,"Data",df_Lomb["Data"])
df_Finale.insert(1,"Ozone_Lomb",df_Lomb["Ozone"])
df_Finale.insert(2,"Ozone_Riva",df_Riva["Ozone"])




df_Finale
# Out:
#                     Data  Ozone_Lomb  Ozone_Riva
# 0    2021-12-10 00:00:00         7.5         4.0
# 1    2021-12-10 01:00:00        20.8         7.0
# 2    2021-12-10 02:00:00         0.5        14.0
# 3    2021-12-10 03:00:00         0.7        22.0
# 4    2021-12-10 04:00:00         1.5        26.0
# ...                  ...         ...         ...
# 8779 2022-12-10 19:00:00         0.5         5.0
# 8780 2022-12-10 20:00:00         0.5         6.0
# 8781 2022-12-10 21:00:00         0.4         NaN
# 8782 2022-12-10 22:00:00         0.6         NaN
# 8783 2022-12-10 23:00:00         0.6         NaN
#
# [8784 rows x 3 columns]

# %%
#df_Finale=df_Finale.set_index("Data")
df_Finale["Ora"] = df_Finale.set_index("Data").index.hour
df_Finale=df_Finale[(df_Finale["Ora"]<=7) | (df_Finale["Ora"]>=19)]
df_Finale
#display(df_Finale.to_string())
# Out:
#                     Data  Ozone_Lomb  Ozone_Riva  Ora
# 0    2021-12-10 00:00:00         7.5         4.0    0
# 1    2021-12-10 01:00:00        20.8         7.0    1
# 2    2021-12-10 02:00:00         0.5        14.0    2
# 3    2021-12-10 03:00:00         0.7        22.0    3
# 4    2021-12-10 04:00:00         1.5        26.0    4
# ...                  ...         ...         ...  ...
# 8779 2022-12-10 19:00:00         0.5         5.0   19
# 8780 2022-12-10 20:00:00         0.5         6.0   20
# 8781 2022-12-10 21:00:00         0.4         NaN   21
# 8782 2022-12-10 22:00:00         0.6         NaN   22
# 8783 2022-12-10 23:00:00         0.6         NaN   23
#
# [4758 rows x 4 columns]

# %%
df_Finale=df_Finale.set_index("Data")
df_Finale.dropna(inplace=True)
df_Finale
# Out:
#                      Ozone_Lomb  Ozone_Riva  Ora
# Data
# 2021-12-10 00:00:00         7.5         4.0    0
# 2021-12-10 01:00:00        20.8         7.0    1
# 2021-12-10 02:00:00         0.5        14.0    2
# 2021-12-10 03:00:00         0.7        22.0    3
# 2021-12-10 04:00:00         1.5        26.0    4
# ...                         ...         ...  ...
# 2022-12-10 05:00:00         0.4        10.0    5
# 2022-12-10 06:00:00         0.2         4.0    6
# 2022-12-10 07:00:00         0.2         6.0    7
# 2022-12-10 19:00:00         0.5         5.0   19
# 2022-12-10 20:00:00         0.5         6.0   20
#
# [4687 rows x 3 columns]

# %%
LR =LinearRegression()
LR.fit(df_Finale["Ozone_Lomb"].values.reshape(-1,1),df_Finale["Ozone_Riva"].values)
prediction = LR.predict(df_Finale["Ozone_Lomb"].values.reshape(-1,1))
plt.plot(df_Finale["Ozone_Lomb"], prediction, label="Linear Regression", color="b")
plt.scatter(df_Finale["Ozone_Lomb"],df_Finale["Ozone_Riva"], label="Actual Data", color ="g", alpha=.7)
plt.legend()
plt.title(" Regression Lombardia and Riva\n"+start_date+" to "+end_date+"\n19:00 --> 7:00")
plt.xlabel("Ozone-Lombardia")
plt.ylabel("Ozone-Riva")
plt.show()
regress_info=linregress(df_Finale["Ozone_Lomb"], df_Finale["Ozone_Riva"])
print(linregress(df_Finale["Ozone_Lomb"], df_Finale["Ozone_Riva"]))
# Out:
# LinregressResult(slope=0.7531163363679615, intercept=4.295372076349018, rvalue=0.8296848451461712, pvalue=0.0, stderr=0.00740301970865914, intercept_stderr=0.5062445621271486)
